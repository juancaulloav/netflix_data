# %%
import numpy as np #linear algebra
import pandas as pd #data processing
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score


# Read the CSV file
df = pd.read_csv('../data/raw/netflix_titles.csv', index_col =  0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 3
#       1 import numpy as np #linear algebra
#       2 import pandas as pd #data processing
# ----> 3 from sklearn.model_selection import train_test_split
#       4 from sklearn.feature_extraction.text import TfidfVectorizer
#       5 from sklearn.ensemble import RandomForestClassifier
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
df.head(5)
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# ...

# %%
#Preprocess the data
df.fillna("", inplace=True)
df.head(5)
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans
# s5       TV Show           Kota Factory
#
#                                                       cast        country  \
# show_id
# s1                                                          United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# s4
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s3       September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
#Esta es una forma de mostrarlo
df.loc["s3"]
# Out:
# type                                                      TV Show
# title                                                   Ganglands
# director                                          Julien Leclercq
# cast            Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# country
# date_added                                     September 24, 2021
# release_year                                                 2021
# rating                                                      TV-MA
# duration                                                 1 Season
# listed_in       Crime TV Shows, International TV Shows, TV Act...
# description     To protect his family from a powerful drug lor...
# Name: s3, dtype: object

# %%
#Así lo podemos mostrar como un dataframe
df.loc[["s1"]]
# Out:
#           type                 title         director cast        country  \
# show_id
# s1       Movie  Dick Johnson Is Dead  Kirsten Johnson       United States
#
#                  date_added  release_year rating duration      listed_in  \
# show_id
# s1       September 25, 2021          2020  PG-13   90 min  Documentaries
#
#                                                description
# show_id
# s1       As her father nears the end of his life, filmm...

# %%
#podemos agregar mas de una fila de esta forma
df.loc[["s1","s5","s20"]]
# Out:
#             type                 title         director  \
# show_id
# s1         Movie  Dick Johnson Is Dead  Kirsten Johnson
# s5       TV Show          Kota Factory
# s20      TV Show                Jaguar
#
#                                                       cast        country  \
# show_id
# s1                                                          United States
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# s20      Blanca Suárez, Iván Marcos, Óscar Casas, Adriá...
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s5       September 24, 2021          2021  TV-MA  2 Seasons
# s20      September 22, 2021          2021  TV-MA   1 Season
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s5       International TV Shows, Romantic TV Shows, TV ...
# ...

# %%
# podemos incluir solo las columnas que nos interesan de esta forma(incluiremos titulo, tipo y descripcion)
df.loc[["s1","s5","s20"], ["title","type","description"]]
# Out:
#                         title     type  \
# show_id
# s1       Dick Johnson Is Dead    Movie
# s5               Kota Factory  TV Show
# s20                    Jaguar  TV Show
#
#                                                description
# show_id
# s1       As her father nears the end of his life, filmm...
# s5       In a city of coaching centers known to train I...
# s20      In the 1960s, a Holocaust survivor joins a gro...

# %%
#Tambien podemos usar loc para seleccionar todas las filas, pero solo un numero especifico de columnas
df.loc[:, ["title","type","description"]]
# Out:
#                          title     type  \
# show_id
# s1        Dick Johnson Is Dead    Movie
# s2               Blood & Water  TV Show
# s3                   Ganglands  TV Show
# s4       Jailbirds New Orleans  TV Show
# s5                Kota Factory  TV Show
# ...                        ...      ...
# s8803                   Zodiac    Movie
# s8804              Zombie Dumb  TV Show
# s8805               Zombieland    Movie
# s8806                     Zoom    Movie
# s8807                   Zubaan    Movie
#
#                                                description
# show_id
# s1       As her father nears the end of his life, filmm...
# s2       After crossing paths at a party, a Cape Town t...
# s3       To protect his family from a powerful drug lor...
# s4       Feuds, flirtations and toilet talk go down amo...
# s5       In a city of coaching centers known to train I...
# ...                                                    ...
# ...

# %%
#con iloc podemos seleccionar utilizando el indice
df.iloc[[0]]
# Out:
#             type          title director  \
# show_id
# s2       TV Show  Blood & Water
#
#                                                       cast       country  \
# show_id
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
#
#                  date_added  release_year rating   duration  \
# show_id
# s2       September 24, 2021          2021  TV-MA  2 Seasons
#
#                                                listed_in  \
# show_id
# s2       International TV Shows, TV Dramas, TV Mysteries
#
#                                                description
# show_id
# s2       After crossing paths at a party, a Cape Town t...

# %%
#podemos seleccionar multiples filas
df.iloc[[0,4,19],[1,0,10]]
# Out:
#                         title     type  \
# show_id
# s1       Dick Johnson Is Dead    Movie
# s5               Kota Factory  TV Show
# s20                    Jaguar  TV Show
#
#                                                description
# show_id
# s1       As her father nears the end of his life, filmm...
# s5       In a city of coaching centers known to train I...
# s20      In the 1960s, a Holocaust survivor joins a gro...

# %%
df.iloc[:,[1,0,10]]
# Out:
#                          title     type  \
# show_id
# s1        Dick Johnson Is Dead    Movie
# s2               Blood & Water  TV Show
# s3                   Ganglands  TV Show
# s4       Jailbirds New Orleans  TV Show
# s5                Kota Factory  TV Show
# ...                        ...      ...
# s8803                   Zodiac    Movie
# s8804              Zombie Dumb  TV Show
# s8805               Zombieland    Movie
# s8806                     Zoom    Movie
# s8807                   Zubaan    Movie
#
#                                                description
# show_id
# s1       As her father nears the end of his life, filmm...
# s2       After crossing paths at a party, a Cape Town t...
# s3       To protect his family from a powerful drug lor...
# s4       Feuds, flirtations and toilet talk go down amo...
# s5       In a city of coaching centers known to train I...
# ...                                                    ...
# ...
